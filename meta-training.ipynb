# %% [markdown]
# ### 가상환경: meta-bert
# - 돌리는건 88서버에서
#
# ### To-Do
# #### BERT-base 위에
# - domain = 'laptop', n = 2, mode = 'random' // 5시간 45분 소요
# - domain = 'laptop', n = 3, mode = 'random' // 7시간 50분 소요
# - domain = 'rest', n = 2, mode = 'random' // 5시간 8분 소요
# - domain = 'rest', n = 3, mode = 'random' // 7시간 42분 소요
# - domain = 'laptop', n = 2, mode = 'curriculum' // 5시간 27분 소요
# - domain = 'laptop', n = 3, mode = 'curriculum'
# - domain = 'rest', n = 2, mode = 'curriculum' // 5시간 8분 소요
# - domain = 'rest', n = 3, mode = 'curriculum'
#
# #### SMLMT 위에
# - domain = 'laptop', n = 2, mode = 'random' // Done
# - domain = 'laptop', n = 3, mode = 'random' // Done (700 task까지만)
# - domain = 'rest', n = 2, mode = 'random' // Done
# - domain = 'rest', n = 3, mode = 'random' // Done
# - domain = 'laptop', n = 2, mode = 'curriculum' // 5시간 19분 소요
# - domain = 'laptop', n = 3, mode = 'curriculum'
# - domain = 'rest', n = 2, mode = 'curriculum' // 5시간 7분 소요
# - domain = 'rest', n = 3, mode = 'curriculum'

# %%
# %%time

# !python run_meta_training.py \
 --train_data task/task_laptop_random_1000_500_3_80_10.json \
 --test_data task/task_laptop_random_10_500_3_80_10_test.json \
 --output_dir results/result_laptop_random_1000_500_3_80_10 \
 --bert_model bert-base-cased \
 --num_labels 3 \
 --num_train_task 50 \
 --gpu_id 0
# Out:
# Namespace(bert_model='bert-base-cased', emb_size=256, epochs=1, gpu_id=0, inner_batch_size=16, inner_update_lr=5e-05, inner_update_step=7, inner_update_step_eval=7, max_seq_length=128, num_labels=3, num_query=10, num_support=80, num_test_task=3, num_train_task=50, outer_batch_size=5, outer_update_lr=1e-05, output_dir='results/result_laptop_random_1000_500_3_80_10', test_data='task/task_laptop_random_10_500_3_80_10_test.json', train_data='task/task_laptop_random_1000_500_3_80_10.json')
# Saving hyperparameters to: results/result_laptop_random_1000_500_3_80_10/hyparams.txt
# Loading Datasets
# ...
